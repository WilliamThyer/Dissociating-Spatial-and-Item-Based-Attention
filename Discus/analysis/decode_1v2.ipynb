# %%
import sys
sys.path.append('../..')

import eeg_decoder
import numpy as np
from collections import OrderedDict
# %load_ext autoreload
# %autoreload 2

# %%
experiment_name = 'd01'
data_dir = f'./data/{experiment_name}'
exp = eeg_decoder.Experiment(experiment_name,data_dir,dev=False,trim_timepoints=[-200,1000])

# %%
time_window = 50
time_step = 25
trial_bin_size = 20
n_splits = 30 
group_dict = OrderedDict([('1',[11]),('2',[20])])
wrangl = eeg_decoder.Wrangler(exp.info['times'],time_window,time_step,trial_bin_size,n_splits,group_dict)
clfr = eeg_decoder.Classification(wrangl,exp.nsub)

# %%
for isub in range(exp.nsub):
    print(isub)
    xdata,ydata = exp.load_eeg(isub)
    xdata,ydata = wrangl.group_labels(xdata,ydata)
    for X_train_all, X_test_all, y_train, y_test in wrangl.bin_and_split_data(xdata,ydata):

        X_train_all, X_test_all, y_train, y_test = wrangl.balance_data(X_train_all, X_test_all, y_train, y_test)
        y_test_shuffle = np.random.permutation(y_test)

        for X_train, X_test in wrangl.roll_over_time(X_train_all, X_test_all):
            clfr.decode(X_train,X_test,y_train,y_test,y_test_shuffle,isub)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-37e63f00480c> in <module>
#       3     xdata,ydata = exp.load_eeg(isub)
#       4     xdata,ydata = wrangl.group_labels(xdata,ydata)
# ----> 5     for X_train_all, X_test_all, y_train, y_test in wrangl.bin_and_split_data(xdata,ydata):
#       6
#       7         X_train_all, X_test_all, y_train, y_test = wrangl.balance_data(X_train_all, X_test_all, y_train, y_test)
#
# d:\Discus\analysis\eeg_decoder.py in bin_and_split_data(self, xdata, ydata, test_size)
#     693
#     694         for self.ifold in range(self.n_splits):
# --> 695             xdata_binned, ydata_binned = self.bin_trials(xdata, ydata)
#     696             X_train_all, X_test_all, y_train, y_test = train_test_split(xdata_binned,ydata_binned,stratify=ydata_binned, test_size=test_size)
#     697
#
# d:\Discus\analysis\eeg_decoder.py in bin_trials(self, xdata, ydata, permute_trials)
#     578                     bin_idx = label_bins == bin
#     579                     # average over data
# --> 580                     bin_average_data[ibin] = np.mean(label_data[bin_idx],0)
#     581
#     582                 xdata_bin.append(bin_average_data)
#
# KeyboardInterrupt:

# %%
interp = eeg_decoder.Interpreter(clfr, subtitle='1Hv1L') 
# interp.save_results()

# %%
import matplotlib.pyplot as plt
interp.plot_acc(significance_testing=False,savefig=False,ylim=[.34,1],chance_text_y=.23, title='',stim_time=[0,200])
plt.show()
# Out:
# No handles with labels found to put in legend.
# Mean delay accuracy: 0.7891927083333333
# Mean delay S.D.: 0.04957308870273393

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_hyperplane(stim_time=[0,200], ylim=[-4,4])
